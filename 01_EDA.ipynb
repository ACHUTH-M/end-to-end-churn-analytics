# %% [markdown]
# <a href="https://colab.research.google.com/github/ACHUTH-M/end-to-end-churn-analytics/blob/main/01_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ACHUTH-M/end-to-end-churn-analytics.git
# Out:
# Cloning into 'end-to-end-churn-analytics'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd end-to-end-churn-analytics
# !ls
# Out:
# /content/end-to-end-churn-analytics
# 01_EDA.ipynb  data  README.md

# %%
import pandas as pd

df = pd.read_csv("data/raw/telco_churn.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2403925900.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("data/raw/telco_churn.csv")
#       4 df.head()
#
# ...
